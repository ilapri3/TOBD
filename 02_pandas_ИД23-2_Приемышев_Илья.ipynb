# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %%
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация 
# об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из 
# файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание 
# на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).
import pandas as pd
import numpy as np
recipes = pd.read_csv('recipes_sample.csv')
reviews = pd.read_csv('reviews_sample.csv')
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.
print(f'Количество строк reviews: {len(reviews.index)}')
print(f'Количество строк recipes: {len(recipes.index)}')
print(f'Количество столбцов reviews: {len(reviews.columns)}')
print(f'Количество столбцов recipes: {len(recipes.columns)}')
print(f'Тип данных reviews: {type(reviews)}')
print(f'Тип данных recipes: {type(recipes)}')
# Out:
# Количество строк reviews: 126696
# Количество строк recipes: 30000
# Количество столбцов reviews: 6
# Количество столбцов recipes: 8
# Тип данных reviews: <class 'pandas.core.frame.DataFrame'>
# Тип данных recipes: <class 'pandas.core.frame.DataFrame'>

# %%
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. 
# # Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.
print('Доля строк для recipes: ', '{:.2f}'.format(len(recipes.dropna().index) / len(recipes.index))) #{:.2f} - ограничение до 2 цифр после запятой
print('Доля строк для reviews: ', '{:.2f}'.format(len(reviews.dropna().index) / len(reviews.index)))
# Out:
# Доля строк для recipes:  0.43
# Доля строк для reviews:  1.00

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
name_columns = recipes.columns
recipes = recipes.fillna(1) #заполняем пропуски единичками, чтобы пустые значения не повлияли на среднее значение

for i in name_columns:
    if recipes[i].dtype != 'object': #если наша ячейка не строка, а что-то числовое
         print(f'Столбец "{i}" среднее значение: {round(np.mean(recipes[i]), 2)}')
# Out:
# Столбец "id" среднее значение: 221879.29
# Столбец "minutes" среднее значение: 123.36
# Столбец "contributor_id" среднее значение: 5635900.57
# Столбец "n_steps" среднее значение: 6.52
# Столбец "n_ingredients" среднее значение: 6.64

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
s_name = recipes['name'].sample(n = 10)

s_name
# Out:
# 18944                                  oatmeal bread  abm
# 13210                            ham and beans  crock pot
# 20997                             plum and prune smoothie
# 16212                                        lime ricotta
# 23162    salada de arroz  rice salad    portuguese brazil
# 3409                   blueberry maple syrup french toast
# 12370                       grandma chics jelly roll 1968
# 2317                         barbs bread   butter pickles
# 5124                                 cheese bread pudding
# 10697                                              fakess
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.reset_index()
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
min_and_ing_recipes = recipes[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)]
min_and_ing_recipes
# Out:
#                                        name      id  minutes  contributor_id  \
# 1        healthy for them  yogurt popsicles   67664       10           91970
# 5                  mennonite  corn fritters   44045       15           41706
# 7                say what   banana sandwich   95926        5          118163
# 28                      quick biscuit bread  302399       20          213909
# 38             amish  cake frosting   icing   44050        5           41706
# ...                                     ...     ...      ...             ...
# 29930                    zucchini cole slaw   57980       20           10113
# 29960               zucchini raisin cookies   41192       20           27643
# 29976                         zucchini tots  505053       20          798181
# 29980  zucchini with jalapeno monterey jack  320622       10          305531
# 29983             zucchini with serrano ham  162411       15          152500
#
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
print(recipes['submitted'].dtype)
recipes['submitted'] = pd.to_datetime(recipes['submitted'])
print(recipes['submitted'].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]

# %%
recipes['submitted']
# Out:
# 0       2002-10-25
# 1       2003-07-26
# 2       2002-08-29
# 3       2002-07-27
# 4       2004-02-23
#            ...
# 29995   2007-11-25
# 29996   2009-08-24
# 29997   2004-11-03
# 29998   2012-08-29
# 29999   2008-04-15
# Name: submitted, Length: 30000, dtype: datetime64[ns]

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes['submitted'].dt.year <= 2010]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      1.0
# 1               91970 2003-07-26      1.0
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %%
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится 
# длина описания рецепта из столбца `description`.
recipes['description_lenght'] = recipes['description'].str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, 
# чтобы каждое слово в названии начиналось с прописной буквы.
recipes['name'] = recipes['name'].str.title()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится 
# количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). 
# Обратите внимание, что между словами может располагаться несколько пробелов подряд.
recipes['name_word_count'] = recipes['name'].str.split().str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). 
# Какой участник добавил максимальное кол-во рецептов?
recipes.groupby('contributor_id').count()['name']
# Out:
# contributor_id
# 1530            5
# 1533          186
# 1534           50
# 1535           40
# 1538            8
#              ...
# 2001968497      2
# 2002059754      1
# 2002234079      1
# 2002234259      1
# 2002247884      1
# Name: name, Length: 8404, dtype: int64

# %%
recipes.groupby('contributor_id').count().max()['name']
# Out:
# 421

# %%
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. 
# Для скольких рецептов отсутствуют отзывы? Обратите внимание, 
# что отзыв с нулевым рейтингом или не заполненным текстовым 
# описанием не считается отсутствующим.

reviews.groupby('recipe_id')['rating'].mean()
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64

# %%
print(reviews['review'])
print('------')
print(reviews['review'].dropna())
# Out:
# 0         Last week whole sides of frozen salmon fillet ...
# 1         So simple and so tasty!  I used a yellow capsi...
# 2         Very nice breakfast HH, easy to make and yummy...
# 3         These are a favorite for the holidays and so e...
# 4         Excellent soup!  The tomato flavor is just gre...
#                                 ...
# 126691    This recipe was great! I made it last night. I...
# 126692    This recipe is outstanding. I followed the rec...
# 126693    Well, we were not a crowd but it was a fabulou...
# 126694    I have been a steak eater and dedicated BBQ gr...
# 126695    Wonderful and simple to prepare seasoning blen...
# Name: review, Length: 126696, dtype: object
# ------
# 0         Last week whole sides of frozen salmon fillet ...
# 1         So simple and so tasty!  I used a yellow capsi...
# 2         Very nice breakfast HH, easy to make and yummy...
# 3         These are a favorite for the holidays and so e...
# ...

# %%
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.
recipes.groupby('submitted').count().sort_values('id')['id']
# Out:
# submitted
# 1999-08-06     1
# 2012-02-16     1
# 2012-02-15     1
# 2012-02-13     1
# 2012-02-12     1
#               ..
# 2008-01-22    46
# 2006-06-17    47
# 2008-01-03    50
# 2005-04-12    58
# 2002-03-28    60
# Name: id, Length: 4032, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %%
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, 
# состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. 
#     Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. 
#     Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, 
#     и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.
new_table = pd.merge(recipes, reviews, left_on = 'id', right_on = 'recipe_id')
new_table = new_table[new_table['review'].notnull()]
new_table
# Out:
#                                           name      id  minutes  \
# 0        George S At The Cove  Black Bean Soup   44123       90
# 1        George S At The Cove  Black Bean Soup   44123       90
# 2        George S At The Cove  Black Bean Soup   44123       90
# 3           Healthy For Them  Yogurt Popsicles   67664       10
# 4           Healthy For Them  Yogurt Popsicles   67664       10
# ...                                        ...     ...      ...
# 126691                             Zydeco Soup  486161       60
# 126692                             Zydeco Soup  486161       60
# 126693                             Zydeco Soup  486161       60
# 126694                             Zydeco Soup  486161       60
# 126695  Cookies By Design   Cookies On A Stick  298512       29
#
#         contributor_id   submitted  n_steps  \
# 0                35193  2002-10-25      NaN
# 1                35193  2002-10-25      NaN
# 2                35193  2002-10-25      NaN
# ...

# %%
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: 
#     `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, 
#     оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, 
#     в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, 
#     выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.
new_table_2 = pd.merge(recipes, reviews, left_on = 'id', right_on = 'recipe_id')
new_table_2 = new_table_2[['recipe_id', 'name']]
for i in range(1):
    ind = reviews.groupby('recipe_id')['review'].count().index[i]
    new_table_2['review_count'] = reviews.groupby('recipe_id')['review'].count()[ind]
new_table_2
# Out:
#         recipe_id                                    name  review_count
# 0           44123   George S At The Cove  Black Bean Soup             2
# 1           44123   George S At The Cove  Black Bean Soup             2
# 2           44123   George S At The Cove  Black Bean Soup             2
# 3           67664      Healthy For Them  Yogurt Popsicles             2
# 4           67664      Healthy For Them  Yogurt Popsicles             2
# ...           ...                                     ...           ...
# 126691     486161                             Zydeco Soup             2
# 126692     486161                             Zydeco Soup             2
# 126693     486161                             Zydeco Soup             2
# 126694     486161                             Zydeco Soup             2
# 126695     298512  Cookies By Design   Cookies On A Stick             2
#
# [126696 rows x 3 columns]

# %%
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?
new_table_3 = pd.merge(recipes, reviews, left_on = 'id', right_on = 'recipe_id')
new_table_3
# Out:
#                                           name      id  minutes  \
# 0        George S At The Cove  Black Bean Soup   44123       90
# 1        George S At The Cove  Black Bean Soup   44123       90
# 2        George S At The Cove  Black Bean Soup   44123       90
# 3           Healthy For Them  Yogurt Popsicles   67664       10
# 4           Healthy For Them  Yogurt Popsicles   67664       10
# ...                                        ...     ...      ...
# 126691                             Zydeco Soup  486161       60
# 126692                             Zydeco Soup  486161       60
# 126693                             Zydeco Soup  486161       60
# 126694                             Zydeco Soup  486161       60
# 126695  Cookies By Design   Cookies On A Stick  298512       29
#
#         contributor_id   submitted  n_steps  \
# 0                35193  2002-10-25      NaN
# 1                35193  2002-10-25      NaN
# 2                35193  2002-10-25      NaN
# ...

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %%
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и 
# сохраните результаты выполнения заданий 3.1-3.3 в csv файл. 
recipes.sort_values('name_word_count')[::-1].to_csv('new_recipes.csv')

# %%
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: 
#     на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; 
#     на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.
new_table.to_excel('excel_5.1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# IllegalCharacterError                     Traceback (most recent call last)
# Cell In[24], line 4
#       1 # 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл:
#       2 #     на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1;
#       3 #     на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.
# ----> 4 new_table.to_excel('excel_5.1.xlsx')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
# ...
